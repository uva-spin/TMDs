# %%
import lhapdf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
from Global_Constants import *
from Sivers_SIDIS_Definitions import *
from Sivers_DY_Definitions import *

from iminuit import Minuit
import numpy as np
#import tabulate as tab

# %%
def SIDIStotalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    datfilesarray=SIDIS_DataFilesArray
    datfilesnum=len(datfilesarray)
    temptotal=[]
    temptotaldata=[]
    temptotalerr=[]
    for i in range(0,datfilesnum):
        temptotal.append(totalfitDataSet(datfilesarray[i],m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar))
        temptotaldata.append(np.concatenate(ASiv_Val(datfilesarray[i])))
        temptotalerr.append(np.concatenate(ASiv_Err(datfilesarray[i])))
    tempTheory=np.concatenate((temptotal))
    tempY=np.concatenate((temptotaldata))
    tempYErr=np.concatenate((temptotalerr))
    tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
    return tempChi2


# def DYtotalchi2MinuitTest(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
#     DY_datfilesarray=DY_DataFilesArray
#     DY_datfilesnum=len(DY_datfilesarray)
#     temptotal=[]
#     for i in range(0,DY_datfilesnum):
#         temptotal.append(DYtotalfitDataSet(DY_datfilesarray[i],m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar))
#     tempTheory=np.concatenate((temptotal), axis=None)
#     tempY=DYSiversVals(DY_datfilesarray)
#     tempYErr=DYSiversErrVals(DY_datfilesarray)
#     tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
#     return tempChi2

def DYtotalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    DY_datfilesarray=DY_DataFilesArray
    DY_datfilesnum=len(DY_datfilesarray)
    temptotal=[]
    for i in range(0,DY_datfilesnum):
        temptotal.append(DYtotalfitDataSets(DY_datfilesarray,m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar))
    tempTheory=np.concatenate((temptotal), axis=None)
    tempY=DYSiversVals(DY_datfilesarray)
    tempYErr=DYSiversErrVals(DY_datfilesarray)
    tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
    return tempChi2


def totalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    tempchi2=SIDIStotalchi2Minuit(m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar)+ DYtotalchi2Minuit(m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar)
    return tempchi2

#m = Minuit(totalchi2Minuit,m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2)
#m.migrad()
#m.values()

ms = Minuit(totalchi2Minuit,m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2)
ms.migrad()
# Out:
# <ipython-input-2-6640a779c904>:51: InitialParamWarning: errordef is not given, defaults to 1.
#   ms = Minuit(totalchi2Minuit,m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2)
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 864.5                      │       Nfcn = 2355 (2355 total)       │
# │ EDM = 0.0491 (Goal: 0.0002)      │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │        No Parameters at limit        │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name   │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1     │    5.7    │    0.8    │            │            │         │         │       │
# │ 1 │ Nu     │   0.69    │   0.08    │            │            │         │         │       │
# │ 2 │ alphau │   2.74    │   0.09    │            │            │         │         │       │
# │ 3 │ betau  │   15.1    │    0.6    │            │            │         │         │       │
# │ 4 │ Nubar  │  -0.107   │   0.017   │            │            │         │         │       │
# │ 5 │ Nd     │   -1.34   │   0.15    │            │            │         │         │       │
# │ 6 │ alphad │    1.6    │    0.4    │            │            │         │         │       │
# │ 7 │ betad  │    5.4    │    2.5    │            │            │         │         │       │
# │ 8 │ Ndbar  │   -0.08   │   0.13    │            │            │         │         │       │
# │ 9 │ Ns     │   11.2    │    1.4    │            │            │         │         │       │
# │ 10│ alphas │   0.85    │   0.09    │            │            │         │         │       │
# │ 11│ betas  │   0.46    │   0.12    │            │            │         │         │       │
# │ 12│ Nsbar  │    0.2    │    0.4    │            │            │         │         │       │
# └───┴────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
def SIDIStotalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    datfilesarray=SIDIS_DataFilesArray
    datfilesnum=len(datfilesarray)
    temptotal=[]
    temptotaldata=[]
    temptotalerr=[]
    for i in range(0,datfilesnum):
        temptotal.append(totalfitDataSet(datfilesarray[i],m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar))
        temptotaldata.append(np.concatenate(ASiv_Val(datfilesarray[i])))
        temptotalerr.append(np.concatenate(ASiv_Err(datfilesarray[i])))
    tempTheory=np.concatenate((temptotal))
    tempY=np.concatenate((temptotaldata))
    tempYErr=np.concatenate((temptotalerr))
    tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
    return tempChi2


# def DYtotalchi2MinuitTest(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
#     DY_datfilesarray=DY_DataFilesArray
#     DY_datfilesnum=len(DY_datfilesarray)
#     temptotal=[]
#     for i in range(0,DY_datfilesnum):
#         temptotal.append(DYtotalfitDataSet(DY_datfilesarray[i],m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar))
#     tempTheory=np.concatenate((temptotal), axis=None)
#     tempY=DYSiversVals(DY_datfilesarray)
#     tempYErr=DYSiversErrVals(DY_datfilesarray)
#     tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
#     return tempChi2

def DYtotalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    DY_datfilesarray=DY_DataFilesArray
    DY_datfilesnum=len(DY_datfilesarray)
    temptotal=[]
    for i in range(0,DY_datfilesnum):
        temptotal.append(DYtotalfitDataSets(DY_datfilesarray,m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar))
    tempTheory=np.concatenate((temptotal), axis=None)
    tempY=DYSiversVals(DY_datfilesarray)
    tempYErr=DYSiversErrVals(DY_datfilesarray)
    tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
    return tempChi2


def totalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    tempchi2=SIDIStotalchi2Minuit(m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar)+ DYtotalchi2Minuit(m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar)
    return tempchi2

#m = Minuit(totalchi2Minuit,m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2)
#m.migrad()
#m.values()

ms = Minuit(totalchi2Minuit,m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2)
ms.migrad()
# Out:
# <ipython-input-29-6640a779c904>:51: InitialParamWarning: errordef is not given, defaults to 1.
#   ms = Minuit(totalchi2Minuit,m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2)
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 864                        │       Nfcn = 2364 (2364 total)       │
# │ EDM = 0.0308 (Goal: 0.0002)      │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │        No Parameters at limit        │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name   │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1     │    6.1    │    0.5    │            │            │         │         │       │
# │ 1 │ Nu     │   0.72    │   0.05    │            │            │         │         │       │
# │ 2 │ alphau │   2.71    │   0.05    │            │            │         │         │       │
# │ 3 │ betau  │   15.05   │   0.30    │            │            │         │         │       │
# │ 4 │ Nubar  │  -0.096   │   0.018   │            │            │         │         │       │
# │ 5 │ Nd     │   -1.30   │   0.11    │            │            │         │         │       │
# │ 6 │ alphad │   1.36    │   0.31    │            │            │         │         │       │
# │ 7 │ betad  │    4.7    │    1.8    │            │            │         │         │       │
# │ 8 │ Ndbar  │   -0.04   │   0.12    │            │            │         │         │       │
# │ 9 │ Ns     │   12.0    │    0.9    │            │            │         │         │       │
# │ 10│ alphas │   0.91    │   0.05    │            │            │         │         │       │
# │ 11│ betas  │   0.52    │   0.07    │            │            │         │         │       │
# │ 12│ Nsbar  │   0.25    │   0.32    │            │            │         │         │       │
# └───┴────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
m.values
# Out:
# <ValueView of Minuit at 345adb0>
#   m1: 6.073437307109219
#   Nu: 0.718213821317266
#   alphau: 2.708622661361662
#   betau: 15.049301570230673
#   Nubar: -0.09640603108483525
#   Nd: -1.3034607727348217
#   alphad: 1.3608809851231953
#   betad: 4.738708783749257
#   Ndbar: -0.04001115282078562
#   Ns: 12.01349575681584
#   alphas: 0.9053006904622889
#   betas: 0.524419088841965
#   Nsbar: 0.25131086041634876

# %%
m.errors
# Out:
# <ErrorView of Minuit at 345adb0>
#   m1: 0.5423617906999285
#   Nu: 0.05254762737641998
#   alphau: 0.04965309827706628
#   betau: 0.2984238379817015
#   Nubar: 0.018030592384485237
#   Nd: 0.10876916614985419
#   alphad: 0.30895570404798833
#   betad: 1.803507484116029
#   Ndbar: 0.12235767152102818
#   Ns: 0.8644718859475596
#   alphas: 0.05398553162209274
#   betas: 0.06924649570482584
#   Nsbar: 0.31996326547007203

# %%
m.covariance
# Out:
# {('m1', 'm1'): 0.2941563120112331,
#  ('m1', 'Nu'): 0.026839007835689845,
#  ('m1', 'alphau'): 0.01018867787926555,
#  ('m1', 'betau'): 0.12421148045818564,
#  ('m1', 'Nubar'): 0.0032804433028575013,
#  ('m1', 'Nd'): -0.009285569992136623,
#  ('m1', 'alphad'): -0.14304525562988182,
#  ('m1', 'betad'): -0.5659959500026368,
#  ('m1', 'Ndbar'): 0.02654548425583324,
#  ('m1', 'Ns'): 0.3922334580878255,
#  ('m1', 'alphas'): 0.017976514215953296,
#  ('m1', 'betas'): 0.03262841949986152,
#  ('m1', 'Nsbar'): 0.07462460834997811,
#  ('Nu', 'm1'): 0.026839007835689845,
#  ('Nu', 'Nu'): 0.0027612531428910826,
#  ('Nu', 'alphau'): 0.0015631048528196112,
#  ('Nu', 'betau'): 0.010383849322467156,
#  ('Nu', 'Nubar'): 0.00030422520764281455,
#  ('Nu', 'Nd'): -0.0013340871262862975,
#  ('Nu', 'alphad'): -0.013511484469543244,
#  ('Nu', 'betad'): -0.05537431351128921,
#  ('Nu', 'Ndbar'): 0.0026762881327407682,
#  ('Nu', 'Ns'): 0.03732183043755291,
#  ('Nu', 'alphas'): 0.0017730300143640435,
#  ('Nu', 'betas'): 0.003109461968364805,
#  ('Nu', 'Nsbar'): 0.007492143509273706,
#  ('alphau', 'm1'): 0.01018867787926555,
#  ('alphau', 'Nu'): 0.0015631048528196112,
#  ('alphau', 'alphau'): 0.0024654301685120023,
#  ('alphau', 'betau'): -0.001746577415912741,
#  ('alphau', 'Nubar'): -5.3445671855876916e-05,
#  ('alphau', 'Nd'): -0.0027790491600544875,
#  ('alphau', 'alphad'): -0.005571688707215418,
#  ('alphau', 'betad'): -0.03797344660245184,
#  ('alphau', 'Ndbar'): 0.002428075476811717,
#  ('alphau', 'Ns'): 0.013811290367248456,
#  ('alphau', 'alphas'): 0.0006357457428334613,
#  ('alphau', 'betas'): 0.0012376617901634825,
#  ('alphau', 'Nsbar'): 0.005767223121192226,
#  ('betau', 'm1'): 0.12421148045818564,
#  ('betau', 'Nu'): 0.010383849322467156,
#  ('betau', 'alphau'): -0.001746577415912741,
#  ('betau', 'betau'): 0.08905678707572882,
#  ('betau', 'Nubar'): 0.0033830600437489413,
#  ('betau', 'Nd'): 0.002470309970024268,
#  ('betau', 'alphad'): -0.048520514579432045,
#  ('betau', 'betad'): -0.07618916385840095,
#  ('betau', 'Ndbar'): 0.001444789489369803,
#  ('betau', 'Ns'): 0.17843567705203642,
#  ('betau', 'alphas'): 0.010558694000455275,
#  ('betau', 'betas'): 0.013759452826877556,
#  ('betau', 'Nsbar'): 0.0221339496130991,
#  ('Nubar', 'm1'): 0.0032804433028575013,
#  ('Nubar', 'Nu'): 0.00030422520764281455,
#  ('Nubar', 'alphau'): -5.3445671855876916e-05,
#  ('Nubar', 'betau'): 0.0033830600437489413,
#  ('Nubar', 'Nubar'): 0.00032510226173545706,
#  ('Nubar', 'Nd'): 0.0006708967991029519,
#  ('Nubar', 'alphad'): 0.0006471772279892376,
#  ('Nubar', 'betad'): 0.017552692311054597,
#  ('Nubar', 'Ndbar'): 0.00019718060670129763,
#  ('Nubar', 'Ns'): 0.0059049524367899495,
#  ('Nubar', 'alphas'): 0.0006584579425512372,
#  ('Nubar', 'betas'): 0.0003314218895868325,
#  ('Nubar', 'Nsbar'): 0.0009875676085995297,
#  ('Nd', 'm1'): -0.009285569992136623,
#  ('Nd', 'Nu'): -0.0013340871262862975,
#  ('Nd', 'alphau'): -0.0027790491600544875,
#  ('Nd', 'betau'): 0.002470309970024268,
#  ('Nd', 'Nubar'): 0.0006708967991029519,
#  ('Nd', 'Nd'): 0.011830731504934586,
#  ('Nd', 'alphad'): 0.0047249561739634086,
#  ('Nd', 'betad'): 0.07954067684637804,
#  ('Nd', 'Ndbar'): -0.0007173978235199374,
#  ('Nd', 'Ns'): 0.01728282501220922,
#  ('Nd', 'alphas'): 0.00196489082453135,
#  ('Nd', 'betas'): 0.0007684949192037149,
#  ('Nd', 'Nsbar'): -0.0033251037474442274,
#  ('alphad', 'm1'): -0.14304525562988182,
#  ('alphad', 'Nu'): -0.013511484469543244,
#  ('alphad', 'alphau'): -0.005571688707215418,
#  ('alphad', 'betau'): -0.048520514579432045,
#  ('alphad', 'Nubar'): 0.0006471772279892376,
#  ('alphad', 'Nd'): 0.0047249561739634086,
#  ('alphad', 'alphad'): 0.09545362706378815,
#  ('alphad', 'betad'): 0.4818301163485723,
#  ('alphad', 'Ndbar'): -0.01383120986605443,
#  ('alphad', 'Ns'): -0.21035228104943388,
#  ('alphad', 'alphas'): -0.006878030579428603,
#  ('alphad', 'betas'): -0.018553858351691183,
#  ('alphad', 'Nsbar'): -0.036342014772165546,
#  ('betad', 'm1'): -0.5659959500026368,
#  ('betad', 'Nu'): -0.05537431351128921,
#  ('betad', 'alphau'): -0.03797344660245184,
#  ('betad', 'betau'): -0.07618916385840095,
#  ('betad', 'Nubar'): 0.017552692311054597,
#  ('betad', 'Nd'): 0.07954067684637804,
#  ('betad', 'alphad'): 0.4818301163485723,
#  ('betad', 'betad'): 3.252639245262529,
#  ('betad', 'Ndbar'): -0.052352210642507974,
#  ('betad', 'Ns'): -0.6832111842845885,
#  ('betad', 'alphas'): 0.0016871179495003136,
#  ('betad', 'betas'): -0.07038793106632425,
#  ('betad', 'Nsbar'): -0.13194840204349906,
#  ('Ndbar', 'm1'): 0.02654548425583324,
#  ('Ndbar', 'Nu'): 0.0026762881327407682,
#  ('Ndbar', 'alphau'): 0.002428075476811717,
#  ('Ndbar', 'betau'): 0.001444789489369803,
#  ('Ndbar', 'Nubar'): 0.00019718060670129763,
#  ('Ndbar', 'Nd'): -0.0007173978235199374,
#  ('Ndbar', 'alphad'): -0.01383120986605443,
#  ('Ndbar', 'betad'): -0.052352210642507974,
#  ('Ndbar', 'Ndbar'): 0.01497139978004783,
#  ('Ndbar', 'Ns'): 0.046262231458361454,
#  ('Ndbar', 'alphas'): 0.002405039084470341,
#  ('Ndbar', 'betas'): 0.0037789673111685938,
#  ('Ndbar', 'Nsbar'): -0.0020597082214065194,
#  ('Ns', 'm1'): 0.3922334580878255,
#  ('Ns', 'Nu'): 0.03732183043755291,
#  ('Ns', 'alphau'): 0.013811290367248456,
#  ('Ns', 'betau'): 0.17843567705203642,
#  ('Ns', 'Nubar'): 0.0059049524367899495,
#  ('Ns', 'Nd'): 0.01728282501220922,
#  ('Ns', 'alphad'): -0.21035228104943388,
#  ('Ns', 'betad'): -0.6832111842845885,
#  ('Ns', 'Ndbar'): 0.046262231458361454,
#  ('Ns', 'Ns'): 0.7473116415937305,
#  ('Ns', 'alphas'): 0.04109118223701657,
#  ('Ns', 'betas'): 0.05920195901897211,
#  ('Ns', 'Nsbar'): 0.1122019013842199,
#  ('alphas', 'm1'): 0.017976514215953296,
#  ('alphas', 'Nu'): 0.0017730300143640435,
#  ('alphas', 'alphau'): 0.0006357457428334613,
#  ('alphas', 'betau'): 0.010558694000455275,
#  ('alphas', 'Nubar'): 0.0006584579425512372,
#  ('alphas', 'Nd'): 0.00196489082453135,
#  ('alphas', 'alphad'): -0.006878030579428603,
#  ('alphas', 'betad'): 0.0016871179495003136,
#  ('alphas', 'Ndbar'): 0.002405039084470341,
#  ('alphas', 'Ns'): 0.04109118223701657,
#  ('alphas', 'alphas'): 0.0029144376245199754,
#  ('alphas', 'betas'): 0.0030055230705546333,
#  ('alphas', 'Nsbar'): 0.005290027633931832,
#  ('betas', 'm1'): 0.03262841949986152,
#  ('betas', 'Nu'): 0.003109461968364805,
#  ('betas', 'alphau'): 0.0012376617901634825,
#  ('betas', 'betau'): 0.013759452826877556,
#  ('betas', 'Nubar'): 0.0003314218895868325,
#  ('betas', 'Nd'): 0.0007684949192037149,
#  ('betas', 'alphad'): -0.018553858351691183,
#  ('betas', 'betad'): -0.07038793106632425,
#  ('betas', 'Ndbar'): 0.0037789673111685938,
#  ('betas', 'Ns'): 0.05920195901897211,
#  ('betas', 'alphas'): 0.0030055230705546333,
#  ('betas', 'betas'): 0.004795077167398463,
#  ('betas', 'Nsbar'): 0.009085499770474305,
#  ('Nsbar', 'm1'): 0.07462460834997811,
#  ('Nsbar', 'Nu'): 0.007492143509273706,
#  ('Nsbar', 'alphau'): 0.005767223121192226,
#  ('Nsbar', 'betau'): 0.0221339496130991,
#  ('Nsbar', 'Nubar'): 0.0009875676085995297,
#  ('Nsbar', 'Nd'): -0.0033251037474442274,
#  ('Nsbar', 'alphad'): -0.036342014772165546,
#  ('Nsbar', 'betad'): -0.13194840204349906,
#  ('Nsbar', 'Ndbar'): -0.0020597082214065194,
#  ('Nsbar', 'Ns'): 0.1122019013842199,
#  ('Nsbar', 'alphas'): 0.005290027633931832,
#  ('Nsbar', 'betas'): 0.009085499770474305,
#  ('Nsbar', 'Nsbar'): 0.10237649125027179}

# %%
m.nfit,m.fval
# Out:
# (13, 864.0175392139805)

# %%
ms.nfit,ms.fval
# Out:
# (13, 864.5062509172467)

# %%
def SIDIStotaldata():
    datfilesarray=SIDIS_DataFilesArray
    datfilesnum=len(datfilesarray)
    temptotaldata=[]
    temptotalerr=[]
    for i in range(0,datfilesnum):
        temptotaldata.append(np.concatenate(ASiv_Val(datfilesarray[i])))
        temptotalerr.append(np.concatenate(ASiv_Err(datfilesarray[i])))
    tempY=np.concatenate((temptotaldata))
    tempYErr=np.concatenate((temptotalerr))
    tempdatalenSIDIS=len(tempY)
    return tempdatalenSIDIS

def DYtotalchi2Minuit():
    DY_datfilesarray=DY_DataFilesArray
    DY_datfilesnum=len(DY_datfilesarray)
    temptotal=[]
    tempY=DYSiversVals(DY_datfilesarray)
    tempYErr=DYSiversErrVals(DY_datfilesarray)
    tempdatalenDY=len(tempY)
    return tempdatalenDY

print(SIDIStotaldata())
print(DYtotalchi2Minuit())
# Out:
# 447
# 15

# %%
print(DYtotalchi2MinuitTest(m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
# Out:
# 13.866812932067543

# %%
print(SIDIStotalchi2Minuit(m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
# Out:
# 888.6075617251687

# %%
print(SIDIS_xFxQ2(SIDIS_PDFs_HERMES_p_2009,2,'pi+',"x"))
# Out:
# [0.41037028 0.52408449 0.58935337 0.63827805 0.68225286 0.69467405
#  0.61420247]

# %%
print(SIDIS_zFzQ(SIDIS_FFs_PiP_HERMES_p_2009,2,'pi+',"x"))
# Out:
# [0.78939765 0.71418368 0.666541   0.62674023 0.5978306  0.57481395
#  0.55887846]

# %%
print(SIDIS_xFxQ2(SIDIS_PDFs_HERMES_p_2009,2,'pi+'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-9d3f7c0b6878> in <module>
# ----> 1 print(SIDIS_xFxQ2(SIDIS_PDFs_HERMES_p_2009,2,'pi+'))
#
# TypeError: SIDIS_xFxQ2() takes 2 positional arguments but 3 were given

# %%
print(Asymmetry_for_Hadron(SIDIS_DataFilesArray[0],"pi+",m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
# Out:
# 0     0.021480
# 1     0.031829
# 2     0.040314
# 3     0.048228
# 4     0.053707
# 5     0.055859
# 6     0.055766
# 7     0.007901
# 8     0.017127
# 9     0.026481
# 10    0.036112
# 11    0.045755
# 12    0.046480
# 13    0.027382
# 14    0.011677
# 15    0.022193
# 16    0.029003
# 17    0.034131
# 18    0.041385
# 19    0.054560
# 20    0.076219
# dtype: float64

# %%
print(Asymmetry_for_Hadron(SIDIS_DataFilesArray[3],"pi+","x",m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
# Out:
# 0   -0.003066
# 1   -0.001634
# 2    0.000321
# 3    0.003893
# 4    0.011089
# 5    0.026046
# 6    0.050825
# 7    0.067605
# 8    0.036687
# dtype: float64

# %%
print(totalfitDataSet(SIDIS_DataFilesArray[0],m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e695107cd04e> in <module>
# ----> 1 print(totalfitDataSet(SIDIS_DataFilesArray[0],m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
#
# ~/Documents/TMDs/Copy-from-uva-spin-github/Fits_Sivers_SIDIS_DY/Sivers_SIDIS_Definitions.py in totalfitDataSet(datfile, m1, Nu, alphau, betau, Nubar, Nd, alphad, betad, Ndbar, Ns, alphas, betas, Nsbar)
#     284             tempfitz=Asymmetry_for_Hadron(datfile,"pi+","z",m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar)
#     285             tempfitphT=Asymmetry_for_Hadron(datfile,"pi+","phT",m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar)
# --> 286             tempfit=np.concatenate(tempfitx,tempfitz,tempfitphT)
#     287             fittot.append(tempfit)
#     288         elif temHads[i]=="pi-":
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: 'Series' object cannot be interpreted as an integer

# %%
print(np.concatenate(ASiv_Val(SIDIS_DataFilesArray[3])))
len(np.concatenate(ASiv_Val(SIDIS_DataFilesArray[3])))
# Out:
# [0.0074 0.0095 0.0119 0.0171 0.0262 0.0332 0.0246 0.0363 0.0308 0.0213
#  0.0172 0.0149 0.0123 0.0261 0.0289 0.0444 0.02 0.0079 0.02 0.0074 0.0269
#  0.0301 0.0269 0.0266 0.0301 0.0182 0.0032 -0.0041 -0.0118 -0.0072 -0.0031
#  -0.0052 -0.0043 -0.0025 0.0453 0.0018 0.0012 -0.019 0.0042 -0.0068
#  -0.0198 0.0108 -0.0142 -0.0077 0.0013 -0.0129 0.0014 -0.0034 0.0056
#  -0.0138 -0.006 -0.0061 -0.0415 0.0353 -0.0029 -0.0074 0.0152 0.0227
#  0.0069 -0.0081 0.0325 0.0171 -0.0009 0.0166 0.0303 -0.0149 -0.0148 0.0159
#  0.0554 0.03 -0.0175 -0.0297 0.0322 0.0024 0.0015 0.0291 -0.0051 0.0619
#  -0.0383 0.0132 0.0281 0.0147 0.0407 0.0474 0.0724 0.0751 0.0521 -0.0029
#  -0.0001 0.0428 0.0056 0.0403 0.043 0.0794 0.0905 0.027 0.0223 0.038
#  0.0266 0.0392 0.026 0.0401 0.0266 0.0311]
# 104

# %%
print(Asymmetry_for_Hadron(SIDIS_DataFilesArray[1],"pi+","x",m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
# Out:
# 0    0.007856
# 1    0.017089
# 2    0.025593
# 3    0.034002
# 4    0.034002
# 5    0.042617
# 6    0.048160
# 7    0.032626
# dtype: float64

# %%
print(totalfitDataSet(SIDIS_DataFilesArray[3],m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
len(totalfitDataSet(SIDIS_DataFilesArray[3],m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2))
# Out:
# [-0.0030663  -0.00163362  0.00032097  0.00389272  0.01108877  0.02604634
#   0.05082472  0.06760483  0.03668737  0.01047624  0.013483    0.01683821
#   0.01985954  0.02358268  0.02753795  0.02580429  0.01749988  0.0055605
#   0.00894184  0.01199192  0.01541309  0.01903567  0.02357666  0.02995398
#   0.0402471   0.07020666 -0.00712562 -0.00653794 -0.00557467 -0.00420948
#  -0.00214714  0.00230246  0.00974789  0.01414505 -0.00021508  0.00424195
#   0.0035191   0.00171833 -0.00158923 -0.00880591 -0.01930409 -0.02035584
#  -0.00959691  0.0001977   0.00029559  0.00032532  0.00054126  0.00054314
#  -0.00018431 -0.00209168 -0.00649516 -0.01579867 -0.02599096 -0.00990415
#   0.00423899  0.01448867  0.02286488  0.03322855  0.04959957  0.06852584
#   0.04627182  0.06015843  0.04305907  0.03271668  0.02754535  0.02110817
#   0.01572913  0.01462858  0.01094408  0.00618199  0.01120126  0.01600451
#   0.02067176  0.02530356  0.03016237  0.03607529  0.04645007  0.07631833
#   0.00743801  0.0054949   0.00577853  0.00942796  0.0191617   0.03961225
#   0.0717788   0.09125859  0.04430431  0.01221311  0.01711167  0.0219405
#   0.02547945  0.02874202  0.02812604  0.01958349  0.0048094   0.00644179
#   0.01128884  0.01578305  0.02022188  0.02450927  0.02984296  0.03687709
#   0.04881395  0.08258947]
# 104

# %%
def Fitvalues(mfit):
    centralvals=mfit.values
    errors=mfit.errors
    return centralvals,errors

print(Fitvalues(m))
# Out:
# (<ValueView of Minuit at 345adb0>
#   m1: 6.073437307109219
#   Nu: 0.718213821317266
#   alphau: 2.708622661361662
#   betau: 15.049301570230673
#   Nubar: -0.09640603108483525
#   Nd: -1.3034607727348217
#   alphad: 1.3608809851231953
#   betad: 4.738708783749257
#   Ndbar: -0.04001115282078562
#   Ns: 12.01349575681584
#   alphas: 0.9053006904622889
#   betas: 0.524419088841965
#   Nsbar: 0.25131086041634876, <ErrorView of Minuit at 345adb0>
#   m1: 0.5423617906999285
#   Nu: 0.05254762737641998
#   alphau: 0.04965309827706628
#   betau: 0.2984238379817015
#   Nubar: 0.018030592384485237
#   Nd: 0.10876916614985419
#   alphad: 0.30895570404798833
#   betad: 1.803507484116029
#   Ndbar: 0.12235767152102818
#   Ns: 0.8644718859475596
#   alphas: 0.05398553162209274
#   betas: 0.06924649570482584
#   Nsbar: 0.31996326547007203)

# %%
def SIDIStotalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    datfilesarray=SIDIS_DataFilesArray
    datfilesnum=len(datfilesarray)
    temptotal=[]
    temptotaldata=[]
    temptotalerr=[]
    for i in range(0,datfilesnum):
        temptotal.append(totalfitDataSet(datfilesarray[i],m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar))
        temptotaldata.append(np.concatenate(ASiv_Val(datfilesarray[i])))
        temptotalerr.append(np.concatenate(ASiv_Err(datfilesarray[i])))
    tempTheory=np.concatenate((temptotal))
    tempY=np.concatenate((temptotaldata))
    tempYErr=np.concatenate((temptotalerr))
    tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
    return tempChi2


# def DYtotalchi2MinuitTest(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
#     DY_datfilesarray=DY_DataFilesArray
#     DY_datfilesnum=len(DY_datfilesarray)
#     temptotal=[]
#     for i in range(0,DY_datfilesnum):
#         temptotal.append(DYtotalfitDataSet(DY_datfilesarray[i],m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar))
#     tempTheory=np.concatenate((temptotal), axis=None)
#     tempY=DYSiversVals(DY_datfilesarray)
#     tempYErr=DYSiversErrVals(DY_datfilesarray)
#     tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
#     return tempChi2

def DYtotalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    DY_datfilesarray=DY_DataFilesArray
    DY_datfilesnum=len(DY_datfilesarray)
    temptotal=[]
    for i in range(0,DY_datfilesnum):
        temptotal.append(DYtotalfitDataSets(DY_datfilesarray,m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar))
    tempTheory=np.concatenate((temptotal), axis=None)
    tempY=DYSiversVals(DY_datfilesarray)
    tempYErr=DYSiversErrVals(DY_datfilesarray)
    tempChi2=np.sum(((tempY-tempTheory)/tempYErr)**2)
    return tempChi2


def totalchi2Minuit(m1,Nu,alphau,betau,Nubar,Nd,alphad,betad,Ndbar,Ns,alphas,betas,Nsbar):
    tempchi2=SIDIStotalchi2Minuit(m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar)+ DYtotalchi2Minuit(m1=m1,Nu=Nu,alphau=alphau,betau=betau,Nubar=Nubar,Nd=Nd,alphad=alphad,betad=betad,Ndbar=Ndbar,Ns=Ns,alphas=alphas,betas=betas,Nsbar=Nsbar)
    return tempchi2

#m = Minuit(totalchi2Minuit,m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2)
#m.migrad()
#m.values()

ms = Minuit(totalchi2Minuit,m1=M1_t2,Nu=NU_t2,alphau=AlphaU_t2,betau=BetaU_t2,Nubar=NUbar_t2,Nd=ND_t2,alphad=AlphaD_t2,betad=BetaD_t2,Ndbar=NDbar_t2,Ns=NS_t2,alphas=AlphaS_t2,betas=BetaS_t2,Nsbar=NSbar_t2)
ms.migrad()
