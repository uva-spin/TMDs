# %%
import lhapdf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from Input_Parameterization import *
from Sivers_SIDIS_Definitions import *
from Paths import *
from Constants import *

from iminuit import Minuit
import numpy as np

# %%
def totalchi2Minuit(m1,Nu,au,bu,Nub,Nd,ad,bd,Ndb):
    tempchi2=SIDIStotalchi2Minuit(m1=m1,Nu=Nu,au=au,bu=bu,Nub=Nub,Nd=Nd,ad=ad,bd=bd,
                                  Ndb=Ndb)
    return tempchi2

# %%
totalchi2Minuit(5.35,0.62,2.537,13.82,-0.189,-1.15,2.2,9.12,-0.16)
# Out:
# 613.8945000791393

# %%
# m1v=5.35
# Nuv=0.62
# auv=2.537
# buv=13.82
# Nubv=-0.189
# aubv=0
# bubv=0
# Ndv=-1.15
# adv=2.2
# bdv=9.12
# Ndbv=-0.16
# adbv=0
# bdbv=0
# Nsv=10.09
# asv=0.497
# bsv=0.066
# Nsbv=0.18
# asbv=0
# bsbv=0

# M1_test=1.303
# AlphaU_test=0.6455
# BetaU_test=3.122
# AlphaD_test=1.777
# BetaD_test=7.788
# AlphaS_test=0.00006887
# BetaS_test=0.0000000005537
# NU_test=0.1695
# NUbar_test=0.007605
# ND_test=-0.4345
# NDbar_test=-0.1420
# NS_test=0.5626
# NSbar_test=-0.1221

M1_test=0.8
AlphaU_test=1.0
BetaU_test=6.6
AlphaD_test=1.9
BetaD_test=10
AlphaS_test= 0
BetaS_test= 0
NU_test=0.18
NUbar_test=-0.01
ND_test=-0.52
NDbar_test=-0.06
NS_test = 0
NSbar_test = 0

m1v = M1_test

Nuv = NU_test
auv = AlphaU_test
buv = BetaU_test

Nubv = NUbar_test
# aubv = 1
# bubv = 1

Ndv = ND_test
adv = AlphaD_test
bdv = BetaD_test

Ndbv = NDbar_test
# adbv = 1
# bdbv = 1

# Nsv = NS_test
# asv = AlphaS_test
# bsv = BetaS_test

# Nsbv = NSbar_test
# asbv = 1
# bsbv = 1

# %%
ms = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
limit_m1=(0.5,7),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 544.9                      │       Nfcn = 1516 (1516 total)       │
# │ EDM = 0.014 (Goal: 0.0002)       │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │        No Parameters at limit        │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │   3.87    │   0.31    │            │            │   0.5   │    7    │       │
# │ 1 │ Nu   │   0.475   │   0.030   │            │            │         │         │       │
# │ 2 │ au   │   2.41    │   0.16    │            │            │    0    │   20    │       │
# │ 3 │ bu   │   15.0    │    1.4    │            │            │    0    │   20    │       │
# │ 4 │ Nub  │  -0.032   │   0.017   │            │            │         │         │       │
# │ 5 │ Nd   │   -1.25   │   0.19    │            │            │         │         │       │
# │ 6 │ ad   │    1.5    │    0.4    │            │            │    0    │   20    │       │
# │ 7 │ bd   │    7.0    │    2.6    │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   -0.05   │   0.11    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
m1v=0
Nuv=0
auv=0
buv=0
Nubv=0
Ndv=0
adv=0
bdv=0
Ndbv=0

ms2 = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
limit_m1=(0,7),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms2.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 1422                       │       Nfcn = 1520 (1520 total)       │
# │ EDM = 0.0452 (Goal: 0.0002)      │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │       SOME Parameters at limit       │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │   0.045   │   0.026   │            │            │    0    │    7    │       │
# │ 1 │ Nu   │   0.017   │   0.018   │            │            │         │         │       │
# │ 2 │ au   │    4.2    │    1.9    │            │            │    0    │   20    │       │
# │ 3 │ bu   │    19     │    12     │            │            │    0    │   20    │       │
# │ 4 │ Nub  │   0.000   │   0.005   │            │            │         │         │       │
# │ 5 │ Nd   │   -0.01   │   0.04    │            │            │         │         │       │
# │ 6 │ ad   │   0.03    │   0.23    │            │            │    0    │   20    │       │
# │ 7 │ bd   │    19     │    16     │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   0.002   │   0.025   │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
m1v=5.35
Nuv=0.62
auv=2.537
buv=13.82
Nubv=-0.189
Ndv=-1.15
adv=2.2
bdv=9.12
Ndbv=-0.16


ms3 = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
limit_m1=(0,7),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms3.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 534.9                      │       Nfcn = 1032 (1032 total)       │
# │ EDM = 9.76e-05 (Goal: 0.0002)    │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │ Valid Minimum │ Valid Parameters │       SOME Parameters at limit       │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │    7.0    │    1.2    │            │            │    0    │    7    │       │
# │ 1 │ Nu   │   0.86    │   0.05    │            │            │         │         │       │
# │ 2 │ au   │   2.89    │   0.10    │            │            │    0    │   20    │       │
# │ 3 │ bu   │    20     │     5     │            │            │    0    │   20    │       │
# │ 4 │ Nub  │   -0.08   │   0.05    │            │            │         │         │       │
# │ 5 │ Nd   │   -2.25   │   0.33    │            │            │         │         │       │
# │ 6 │ ad   │    2.4    │    0.5    │            │            │    0    │   20    │       │
# │ 7 │ bd   │    15     │     4     │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   -0.11   │   0.25    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
m1v=5.35
Nuv=0.62
auv=2.537
buv=13.82
Nubv=-0.189
Ndv=-1.15
adv=2.2
bdv=9.12
Ndbv=-0.16


ms4 = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
limit_m1=(0,10),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms4.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 533.5                      │       Nfcn = 1030 (1030 total)       │
# │ EDM = 5.01e-06 (Goal: 0.0002)    │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │ Valid Minimum │ Valid Parameters │       SOME Parameters at limit       │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │    10     │     7     │            │            │    0    │   10    │       │
# │ 1 │ Nu   │   1.22    │   0.07    │            │            │         │         │       │
# │ 2 │ au   │   2.88    │   0.10    │            │            │    0    │   20    │       │
# │ 3 │ bu   │    20     │    13     │            │            │    0    │   20    │       │
# │ 4 │ Nub  │   -0.11   │   0.07    │            │            │         │         │       │
# │ 5 │ Nd   │   -3.2    │    0.5    │            │            │         │         │       │
# │ 6 │ ad   │    2.4    │    0.5    │            │            │    0    │   20    │       │
# │ 7 │ bd   │   14.9    │    3.5    │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   -0.2    │    0.4    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
m1v=3.87
Nuv=0.475
auv=2.41
buv=15
Nubv=-0.32
Ndv=-1.25
adv=1.5
bdv=7.0
Ndbv=-0.05


ms7 = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
limit_m1=(0,10),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms7.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 533.5                      │       Nfcn = 1226 (1226 total)       │
# │ EDM = 0.000102 (Goal: 0.0002)    │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │ Valid Minimum │ Valid Parameters │       SOME Parameters at limit       │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │    10     │     7     │            │            │    0    │   10    │       │
# │ 1 │ Nu   │   1.22    │   0.07    │            │            │         │         │       │
# │ 2 │ au   │   2.88    │   0.10    │            │            │    0    │   20    │       │
# │ 3 │ bu   │    20     │    13     │            │            │    0    │   20    │       │
# │ 4 │ Nub  │   -0.11   │   0.07    │            │            │         │         │       │
# │ 5 │ Nd   │   -3.2    │    0.5    │            │            │         │         │       │
# │ 6 │ ad   │    2.4    │    0.5    │            │            │    0    │   20    │       │
# │ 7 │ bd   │   14.9    │    3.5    │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   -0.2    │    0.4    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
m1v=3.87
Nuv=0.475
auv=2.41
buv=15
Nubv=-0.32
Ndv=-1.25
adv=1.5
bdv=7.0
Ndbv=-0.05


ms8 = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
limit_m1=(0,np.infty),
limit_au=(0,np.infty),limit_bu=(0,np.infty),
limit_ad=(0,np.infty),limit_bd=(0,np.infty),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms8.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 532.1                      │       Nfcn = 1078 (1078 total)       │
# │ EDM = 5.7e-06 (Goal: 0.0002)     │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │ Valid Minimum │ Valid Parameters │       SOME Parameters at limit       │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │   0.5e3   │   0.5e3   │            │            │    0    │         │       │
# │ 1 │ Nu   │    60     │    80     │            │            │         │         │       │
# │ 2 │ au   │    3.2    │    0.7    │            │            │    0    │         │       │
# │ 3 │ bu   │    23     │     8     │            │            │    0    │         │       │
# │ 4 │ Nub  │    -6     │     8     │            │            │         │         │       │
# │ 5 │ Nd   │  -0.16e3  │  0.20e3   │            │            │         │         │       │
# │ 6 │ ad   │    2.6    │    0.8    │            │            │    0    │         │       │
# │ 7 │ bd   │    18     │     7     │            │            │    0    │         │       │
# │ 8 │ Ndb  │    -5     │    21     │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
