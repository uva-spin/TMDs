# %%
import lhapdf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import scipy.optimize as opt
from Plot_Definitions import *
from Global_Constants import *

# %%
# Here the data sets are listed and collected into and Array called "DataFilesArray"
Dat1='Data/HERMES_p_2009.csv'
Dat2='Data/HERMES_p_2020.csv'
Dat3='Data/COMPASS_d_2009.csv'
Dat4='Data/COMPASS_p_2015.csv'


### Here you can define arrays of data sets
DataFilesArray_1=[Dat1]
DataFilesArray_2=[Dat2]
print(SIDIS_DataFilesArray)
# Out:
# ['Data/HERMES_p_2009.csv', 'Data/HERMES_p_2020.csv', 'Data/COMPASS_d_2009.csv', 'Data/COMPASS_p_2015.csv']

# %%
### Here we need to provide the fit results

result_SIDIS_DY_signflip=np.array([5.7,0.69,2.74,15.1,-0.107,-1.34,1.6,5.4,-0.08,11.2,0.85,0.46,0.2])
result_SIDIS_DY_nosignflip=np.array([6.1,0.72,2.71,15.05,-0.096,-1.3,1.36,4.7,-0.04,12.0,0.91,0.52,0.25])

result_SIDIS_DY_signflip_err=np.array([0.8,0.08,0.09,0.6,0.017,0.15,0.4,2.5,0.13,1.4,0.09,0.12,0.4])
result_SIDIS_DY_nosignflip_err=np.array([0.5,0.05,0.05,0.3,0.018,0.11,0.31,1.8,0.12,0.9,0.05,0.07,0.32])

# %%
### In this step we generate the parameter samples

#test_parm_H2009 = param_samples(DataFilesArray_1,result_Hermes_2009,result_Hermes_2009_err)

### uncomment the following line to enable preparing parameters for HERMES 2020

#test_parm_H2020 = param_samples(DataFilesArray_2,result_Hermes_2020,result_Hermes_2020_err)

#test_parm_Fit1 = param_samples(SIDIS_DataFilesArray,result_SIDIS_Fit1,result_SIDIS_Fit1_err)

test_parm_sign_Fit2 = param_samples(SIDIS_DataFilesArray,result_SIDIS_DY_signflip,result_SIDIS_DY_signflip_err)
#test_parm_nosign_Fit2 = param_samples(SIDIS_DataFilesArray,result_SIDIS_DY_nosignflip,result_SIDIS_DY_nosignflip_err)
# Out:
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# [ 5.03250768  0.70305177  2.66220696 15.07358796 -0.10143253 -1.28031833
#   1.33923229  3.30827989 -0.05256805 11.18602047  0.89546474  0.65188853
#   0.27352807]
# [ 5.47502956  0.67758698  2.66028744 14.96525806 -0.12640589 -1.28874655
#   0.66375811  1.67250454 -0.10524523 11.39285876  0.64340777  0.13358338
#   0.61155542]
# [ 6.44414934  0.80801945  2.75986856 15.98741923 -0.11022921 -1.42155207
#   1.31670897  5.69893646 -0.08495047 11.93221363  0.89700026  0.67626783
#   0.23550821]
# [ 6.43272096  0.67401445  2.58021039 13.91560176 -0.11581936 -1.21149088
#   1.50394667  6.79514397 -0.10716683 12.30016405  0.92826996  0.40640679
#  -0.53783211]
# [ 5.19648939  0.60581134  2.70837639 15.48889759 -0.12600079 -1.51466534
#   1.35441271  6.8200634  -0.09546491 10.11971154  0.83778108  0.32281255
#   0.38879141]
# [ 6.93744118  0.72306572  2.69803624 14.58733612 -0.10212209 -1.46331937
#         -1.47353002,  1.75654701,  4.67241763, -0.23976681, 11.70925378,
#          0.87036922,  0.49393805, -0.15451128],
#        [ 5.97895533,  0.65243014,  2.65112926, 15.51740983, -0.11530342,
#         -1.46088755,  1.76689361,  4.635605  ,  0.05710225, 10.99370338,
#          0.81256459,  0.49650731, -0.78059802],
#        [ 4.61260131,  0.62346583,  2.73943865, 13.69691333, -0.13175158,
#         -0.85873187,  2.0325548 ,  5.72922772, -0.11839214, 11.77538061,
#          0.82273136,  0.42323706,  0.49916888],
#        [ 5.91233722,  0.74663296,  2.80772994, 15.61377703, -0.0895369 ,
#         -1.1514679 ,  1.50668382,  6.97134401, -0.16353244, 11.31926526,
#          0.89717489,  0.55232522,  0.53404721]])

# %%
#test_parm_sign_Fit2.tofile('test.txt')
a_file = open("test_file.txt","w")
for row in test_parm_sign_Fit2:
    np.savetxt(a_file, row)
a_file.close()

# %%
### Sivers function behavior *** Note, make sure that we indicate Q2 values corresponding to these plots
f1=plt.figure(1,figsize=(15,10))
plotSiversQBandFill(2,test_parm_Fit1,'blue','$u$',result_SIDIS_Fit1)
plotSiversQBandFill(1,test_parm_Fit1,'red','$d$',result_SIDIS_Fit1)
plotSiversQBandFill(3,test_parm_Fit1,'green','$s$',result_SIDIS_Fit1)
plt.legend(loc=1,fontsize=20,handlelength=3)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylim(-0.06,0.06)
plt.legend(loc=4,fontsize=30,handlelength=3)
f1.tight_layout()
f1.savefig('SIDIS_SiversQ_Global_Fit1_1.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a452812b0f67> in <module>
#       1 ### Sivers function behavior *** Note, make sure that we indicate Q2 values corresponding to these plots
#       2 f1=plt.figure(1,figsize=(15,10))
# ----> 3 plotSiversQBandFill(2,test_parm_Fit1,'blue','$u$',result_SIDIS_Fit1)
#       4 plotSiversQBandFill(1,test_parm_Fit1,'red','$d$',result_SIDIS_Fit1)
#       5 plotSiversQBandFill(3,test_parm_Fit1,'green','$s$',result_SIDIS_Fit1)
#
# NameError: name 'test_parm_Fit1' is not defined

# %%
f2=plt.figure(1,figsize=(15,10))
plotSiversAntiQBandFill(-2,test_parm_Fit1,'blue','$\\bar{u}$',result_SIDIS_Fit1)
plotSiversAntiQBandFill(-1,test_parm_Fit1,'red','$\\bar{d}$',result_SIDIS_Fit1)
plotSiversAntiQBandFill(-3,test_parm_Fit1,'green','$\\bar{s}$',result_SIDIS_Fit1)
plt.legend(loc=1,fontsize=20,handlelength=3)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylim(-0.012,0.012)
plt.legend(loc=4,fontsize=30,handlelength=3)
f2.savefig('SIDIS_SiversAntiQ_Global_Fit1.pdf')

# %%
f3=plt.figure(3,figsize=(15,10))
plotSiversQBandFill(2,test_parm_sign_Fit2,'blue','$u$',result_SIDIS_DY_signflip)
plotSiversQBandFill(1,test_parm_sign_Fit2,'red','$d$',result_SIDIS_DY_signflip)
plotSiversQBandFill(3,test_parm_sign_Fit2,'green','$s$',result_SIDIS_DY_signflip)
plt.legend(loc=1,fontsize=20,handlelength=3)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylim(-0.1,0.1)
plt.legend(loc=4,fontsize=30,handlelength=3)
f3.savefig('SiversQ_DY_SIDIS_signflip.pdf')

# %%
f3=plt.figure(3,figsize=(15,10))
plotSiversQBandFill(2,test_parm_sign_Fit2,'blue','$u$',result_SIDIS_DY_signflip)
plotSiversQBandFill(1,test_parm_sign_Fit2,'red','$d$',result_SIDIS_DY_signflip)
plotSiversQBandFill(3,test_parm_sign_Fit2,'green','$s$',result_SIDIS_DY_signflip)
plt.legend(loc=1,fontsize=20,handlelength=3)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylim(-0.1,0.1)
plt.legend(loc=4,fontsize=30,handlelength=3)
f3.savefig('SiversQ_DY_SIDIS_signflip.pdf')

# %%
f4=plt.figure(4,figsize=(15,10))
plotSiversAntiQBandFill(-2,test_parm_sign_Fit2,'blue','$\\bar{u}$',result_SIDIS_DY_signflip)
plotSiversAntiQBandFill(-1,test_parm_sign_Fit2,'red','$\\bar{d}$',result_SIDIS_DY_signflip)
plotSiversAntiQBandFill(-3,test_parm_sign_Fit2,'green','$\\bar{s}$',result_SIDIS_DY_signflip)
plt.legend(loc=1,fontsize=20,handlelength=3)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylim(-0.01,0.006)
plt.legend(loc=4,fontsize=20,handlelength=3)
plt.ylim(-0.012,0.012)
f4.savefig('SiversAntiQ_DY_SIDIS_signflip.pdf')

# %%
f5=plt.figure(5,figsize=(15,10))
plotSiversQBandFill(2,test_parm_nosign_Fit2,'blue','$u$',result_SIDIS_DY_nosignflip)
plotSiversQBandFill(1,test_parm_nosign_Fit2,'red','$d$',result_SIDIS_DY_nosignflip)
plotSiversQBandFill(3,test_parm_nosign_Fit2,'green','$s$',result_SIDIS_DY_nosignflip)
plt.legend(loc=1,fontsize=20,handlelength=3)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylim(-0.1,0.1)
plt.legend(loc=4,fontsize=30,handlelength=3)
f5.savefig('SiversQ_DY_SIDIS_nosignflip.pdf')

# %%
f5=plt.figure(5,figsize=(15,10))
plotSiversQBandFill(2,test_parm_nosign_Fit2,'blue','$u$',result_SIDIS_DY_nosignflip)
plotSiversQBandFill(1,test_parm_nosign_Fit2,'red','$d$',result_SIDIS_DY_nosignflip)
plotSiversQBandFill(3,test_parm_nosign_Fit2,'green','$s$',result_SIDIS_DY_nosignflip)
plt.legend(loc=1,fontsize=20,handlelength=3)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylim(-0.1,0.1)
plt.legend(loc=4,fontsize=30,handlelength=3)
f5.savefig('SiversQ_DY_SIDIS_nosignflip.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-20a25772af16> in <module>
#       1 f5=plt.figure(5,figsize=(15,10))
# ----> 2 plotSiversQBandFill(2,test_parm_nosign_Fit2,'blue','$u$',result_SIDIS_DY_nosignflip)
#       3 plotSiversQBandFill(1,test_parm_nosign_Fit2,'red','$d$',result_SIDIS_DY_nosignflip)
#       4 plotSiversQBandFill(3,test_parm_nosign_Fit2,'green','$s$',result_SIDIS_DY_nosignflip)
#       5 plt.legend(loc=1,fontsize=20,handlelength=3)
#
# NameError: name 'test_parm_nosign_Fit2' is not defined

# %%
f6=plt.figure(6,figsize=(15,10))
plotSiversAntiQBandFill(-2,test_parm_nosign_Fit2,'blue','$\\bar{u}$',result_SIDIS_DY_nosignflip)
plotSiversAntiQBandFill(-1,test_parm_nosign_Fit2,'red','$\\bar{d}$',result_SIDIS_DY_nosignflip)
plotSiversAntiQBandFill(-3,test_parm_nosign_Fit2,'green','$\\bar{s}$',result_SIDIS_DY_nosignflip)
plt.legend(loc=1,fontsize=20,handlelength=3)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylim(-0.01,0.006)
plt.legend(loc=4,fontsize=20,handlelength=3)
plt.ylim(-0.012,0.012)
f6.savefig('SiversAntiQ_DY_SIDIS_nosignflip.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2e1cb3d8c77a> in <module>
#       1 f6=plt.figure(6,figsize=(15,10))
# ----> 2 plotSiversAntiQBandFill(-2,test_parm_nosign_Fit2,'blue','$\\bar{u}$',result_SIDIS_DY_nosignflip)
#       3 plotSiversAntiQBandFill(-1,test_parm_nosign_Fit2,'red','$\\bar{d}$',result_SIDIS_DY_nosignflip)
#       4 plotSiversAntiQBandFill(-3,test_parm_nosign_Fit2,'green','$\\bar{s}$',result_SIDIS_DY_nosignflip)
#       5 plt.legend(loc=1,fontsize=20,handlelength=3)
#
# NameError: name 'test_parm_nosign_Fit2' is not defined

# %%
dep="x"

f2=plt.figure(2,figsize=(15,10))
#plt.suptitle("HERMES 2009",fontsize=15)
### HERMES 2009
plt.subplot(2,3,1)
plt.xlabel('$x$',fontsize=15)
plt.ylabel('$A_{\pi^+}$',fontsize=15)
PlotSivHadBand(Dat1,"pi+",dep,result_Hermes_2009,test_parm_H2009)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(-0.07,.13) 
plt.legend(loc=1,fontsize=10,handlelength=3)
plt.subplot(2,3,2)
PlotSivHadBand(Dat1,"pi0",dep,result_Hermes_2020,test_parm_H2020)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(-0.07,.13)
plt.legend(loc=1,fontsize=10,handlelength=3)
plt.subplot(2,3,3)
PlotSivHadBand(Dat1,"k+",dep,result_Hermes_2009,test_parm_H2009)
plt.xlabel('$x$',fontsize=15)
plt.ylabel('$A_{\pi^+}$',fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(-0.07,.13)
plt.legend(loc=1,fontsize=10,handlelength=3)
##### HERMES 2020
plt.subplot(2,3,4)
PlotSivHadBand(Dat1,"pi+",dep,result_Hermes_2020,test_parm_H2020)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(-0.07,.13)
plt.legend(loc=1,fontsize=10,handlelength=3)
plt.subplot(2,3,5)
PlotSivHadBand(Dat1,"pi0",dep,result_Hermes_2009,test_parm_H2009)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(-0.07,.13)
plt.legend(loc=1,fontsize=10,handlelength=3)
plt.subplot(2,3,6)
PlotSivHadBand(Dat1,"k+",dep,result_Hermes_2020,test_parm_H2020)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(-0.07,.13)
plt.legend(loc=1,fontsize=10,handlelength=3)
f2.tight_layout()
f2.savefig('Final_Plot_SivAsymmetry.pdf')
