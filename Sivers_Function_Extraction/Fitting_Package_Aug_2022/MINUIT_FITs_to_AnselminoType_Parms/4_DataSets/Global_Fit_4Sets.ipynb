# %%
import lhapdf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from Input_Parameterization import *
from Sivers_SIDIS_Definitions import *
from Sivers_DY_Definitions import * 
from Paths import *
from Constants import *

from iminuit import Minuit
import numpy as np

# %%
def totalchi2Minuit(m1,Nu,au,bu,Nub,Nd,ad,bd,Ndb,Ns,aS,bS,Nsb):
    tempchi2=SIDIStotalchi2Minuit(m1=m1,Nu=Nu,au=au,bu=bu,Nub=Nub,Nd=Nd,ad=ad,bd=bd,
                                  Ndb=Ndb,Ns=Ns,aS=aS,bS=bS,Nsb=Nsb)
    return tempchi2

# %%
totalchi2Minuit(5.35,0.62,2.537,13.82,-0.189,-1.15,2.2,9.12,-0.16,10.09,0.497,0.066,0.18)
# Out:
# 874.0377040328243

# %%
# m1v=5.35
# Nuv=0.62
# auv=2.537
# buv=13.82
# Nubv=-0.189
# aubv=0
# bubv=0
# Ndv=-1.15
# adv=2.2
# bdv=9.12
# Ndbv=-0.16
# adbv=0
# bdbv=0
# Nsv=10.09
# asv=0.497
# bsv=0.066
# Nsbv=0.18
# asbv=0
# bsbv=0

M1_test=1.303
AlphaU_test=0.6455
BetaU_test=3.122
AlphaD_test=1.777
BetaD_test=7.788
AlphaS_test=0.00006887
BetaS_test=0.0000000005537
NU_test=0.1695
NUbar_test=0.007605
ND_test=-0.4345
NDbar_test=-0.1420
NS_test=0.5626
NSbar_test=-0.1221


m1v = M1_test

Nuv = NU_test
auv = AlphaU_test
buv = BetaU_test

Nubv = NUbar_test
# aubv = 1
# bubv = 1

Ndv = ND_test
adv = AlphaD_test
bdv = BetaD_test

Ndbv = NDbar_test
# adbv = 1
# bdbv = 1

Nsv = NS_test
asv = AlphaS_test
bsv = BetaS_test

Nsbv = NSbar_test
# asbv = 1
# bsbv = 1

# %%
ms = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
Ns=Nsv,aS=asv,bS=bsv,Nsb=Nsbv,
limit_m1=(3,7),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
limit_aS=(0,20),limit_bS=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 817.7                      │       Nfcn = 2357 (2357 total)       │
# │ EDM = 0.00692 (Goal: 0.0002)     │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │        No Parameters at limit        │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │   4.41    │   0.33    │            │            │    3    │    7    │       │
# │ 1 │ Nu   │   0.509   │   0.024   │            │            │         │         │       │
# │ 2 │ au   │   2.32    │   0.14    │            │            │    0    │   20    │       │
# │ 3 │ bu   │   13.3    │    1.0    │            │            │    0    │   20    │       │
# │ 4 │ Nub  │  -0.043   │   0.010   │            │            │         │         │       │
# │ 5 │ Nd   │   -1.11   │   0.11    │            │            │         │         │       │
# │ 6 │ ad   │   0.98    │   0.19    │            │            │    0    │   20    │       │
# │ 7 │ bd   │    1.8    │    0.8    │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   -0.18   │   0.10    │            │            │         │         │       │
# │ 9 │ Ns   │   2.80    │   0.24    │            │            │         │         │       │
# │ 10│ aS   │   2.57    │   0.20    │            │            │    0    │   20    │       │
# │ 11│ bS   │   16.4    │    1.2    │            │            │    0    │   20    │       │
# │ 12│ Nsb  │   -0.33   │   0.27    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
ms = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
Ns=Nsv,aS=asv,bS=bsv,Nsb=Nsbv,
limit_m1=(3,7),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
limit_aS=(0,20),limit_bS=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 817.7                      │       Nfcn = 2357 (2357 total)       │
# │ EDM = 0.00692 (Goal: 0.0002)     │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │        No Parameters at limit        │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │   4.41    │   0.33    │            │            │    3    │    7    │       │
# │ 1 │ Nu   │   0.509   │   0.024   │            │            │         │         │       │
# │ 2 │ au   │   2.32    │   0.14    │            │            │    0    │   20    │       │
# │ 3 │ bu   │   13.3    │    1.0    │            │            │    0    │   20    │       │
# │ 4 │ Nub  │  -0.043   │   0.010   │            │            │         │         │       │
# │ 5 │ Nd   │   -1.11   │   0.11    │            │            │         │         │       │
# │ 6 │ ad   │   0.98    │   0.19    │            │            │    0    │   20    │       │
# │ 7 │ bd   │    1.8    │    0.8    │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   -0.18   │   0.10    │            │            │         │         │       │
# │ 9 │ Ns   │   2.80    │   0.24    │            │            │         │         │       │
# │ 10│ aS   │   2.57    │   0.20    │            │            │    0    │   20    │       │
# │ 11│ bS   │   16.4    │    1.2    │            │            │    0    │   20    │       │
# │ 12│ Nsb  │   -0.33   │   0.27    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
m1v=4.3
Nuv=0.5
auv=2.4
buv=13
Nubv=-0.04
Ndv=-1.0
adv=1.0
bdv=2.0
Ndbv=-0.15
Nsv=2.7
asv=2.6
bsv=17.0
Nsbv=-0.30

ms2 = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
Ns=Nsv,aS=asv,bS=bsv,Nsb=Nsbv,
limit_m1=(3,7),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
limit_aS=(0,20),limit_bS=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms2.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 811.6                      │       Nfcn = 2362 (2362 total)       │
# │ EDM = 0.0303 (Goal: 0.0002)      │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │       SOME Parameters at limit       │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │    6.9    │    0.4    │            │            │    3    │    7    │       │
# │ 1 │ Nu   │   0.78    │   0.06    │            │            │         │         │       │
# │ 2 │ au   │   2.38    │   0.10    │            │            │    0    │   20    │       │
# │ 3 │ bu   │   14.3    │    0.8    │            │            │    0    │   20    │       │
# │ 4 │ Nub  │  -0.065   │   0.014   │            │            │         │         │       │
# │ 5 │ Nd   │   -1.32   │   0.18    │            │            │         │         │       │
# │ 6 │ ad   │   1.53    │   0.16    │            │            │    0    │   20    │       │
# │ 7 │ bd   │    6.5    │    1.1    │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   -0.37   │   0.14    │            │            │         │         │       │
# │ 9 │ Ns   │    4.2    │    0.4    │            │            │         │         │       │
# │ 10│ aS   │   2.92    │   0.08    │            │            │    0    │   20    │       │
# │ 11│ bS   │   19.99   │   0.09    │            │            │    0    │   20    │       │
# │ 12│ Nsb  │   -0.7    │    0.4    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
M1_t2 = 5.35
AlphaU_t2=2.537
BetaU_t2=13.82
AlphaD_t2=2.2
BetaD_t2=9.12
AlphaS_t2=0.497
BetaS_t2=0.066
NU_t2=0.62
NUbar_t2=-0.189
ND_t2=-1.15
NDbar_t2=-0.16
NS_t2=10.09
NSbar_t2=-0.18


m1v = M1_t2

Nuv = NU_t2
auv = AlphaU_t2
buv = BetaU_t2

Nubv = NUbar_t2
# aubv = 1
# bubv = 1

Ndv = ND_t2
adv = AlphaD_t2
bdv = BetaD_t2

Ndbv = NDbar_t2
# adbv = 1
# bdbv = 1

Nsv = NS_t2
asv = AlphaS_t2
bsv = BetaS_t2

Nsbv = NSbar_t2
# asbv = 1
# bsbv = 1

ms3 = Minuit(totalchi2Minuit,m1=m1v,Nu=Nuv,au=auv,bu=buv,Nub=Nubv,
Nd=Ndv,ad=adv,bd=bdv,Ndb=Ndbv,
Ns=Nsv,aS=asv,bS=bsv,Nsb=Nsbv,
limit_m1=(3,7),
limit_au=(0,20),limit_bu=(0,20),
limit_ad=(0,20),limit_bd=(0,20),
limit_aS=(0,20),limit_bS=(0,20),
errordef=1)
#ms = Minuit(totalchi2Minuit,m1=M1_init,Nu=NU_init,alphau=AlphaU_init,betau=BetaU_init,Nubar=NUbar_init,Nd=ND_init,alphad=AlphaD_init,betad=BetaD_init,Ndbar=NDbar_init,Ns=NS_init,alphas=AlphaS_init,betas=BetaS_init,Nsbar=NSbar_init)
ms3.migrad()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 848.3                      │       Nfcn = 2349 (2349 total)       │
# │ EDM = 0.0106 (Goal: 0.0002)      │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │       SOME Parameters at limit       │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           ABOVE call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │APPROXIMATE│  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ m1   │   6.96    │   0.15    │            │            │    3    │    7    │       │
# │ 1 │ Nu   │   0.819   │   0.030   │            │            │         │         │       │
# │ 2 │ au   │   2.58    │   0.08    │            │            │    0    │   20    │       │
# │ 3 │ bu   │   14.2    │    0.4    │            │            │    0    │   20    │       │
# │ 4 │ Nub  │  -0.132   │   0.032   │            │            │         │         │       │
# │ 5 │ Nd   │   -1.49   │   0.14    │            │            │         │         │       │
# │ 6 │ ad   │   1.43    │   0.17    │            │            │    0    │   20    │       │
# │ 7 │ bd   │    5.0    │    1.2    │            │            │    0    │   20    │       │
# │ 8 │ Ndb  │   -0.12   │   0.15    │            │            │         │         │       │
# │ 9 │ Ns   │   13.1    │    0.8    │            │            │         │         │       │
# │ 10│ aS   │   0.83    │   0.10    │            │            │    0    │   20    │       │
# │ 11│ bS   │   0.46    │   0.09    │            │            │    0    │   20    │       │
# │ 12│ Nsb  │   0.20    │   0.33    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
